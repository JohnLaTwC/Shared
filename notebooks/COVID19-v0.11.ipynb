# %% [markdown]
# # COVID-19 Indicator feed notebook
#
# Author: @JohnLaTwC
#
# This notebook uses the COVID-19 threat indicator feed from Microsoft. It emits a Yara rule that matches on the COVID-19 indicator feed from Microsoft. You can add this rule as a ruleset on VT to get hunting notifications.
#
# It also can search VirusTotal to find matches.
#
# References:
# * https://www.microsoft.com/security/blog/2020/05/14/open-sourcing-covid-threat-intelligence/
# * https://aka.ms/msft-covid19-Indicators

# %%
feedurl = 'https://raw.githubusercontent.com/Azure/Azure-Sentinel/master/Sample%20Data/Feeds/Microsoft.Covid19.Indicators.csv'

# %%
def get_feed(url):
    import requests
    import pandas as pd
    from io import StringIO
    results = None
    r = requests.get(url)
    if r.status_code==404:
        print('feed does not exist')
    else:
        csv = StringIO(r.content.decode())
        results = pd.read_csv(csv, sep=',', names=["Timestamp", "sha256", "IndicatorType", "TLP", "Product", "ThreatType", "Description"])
    return results

def create_rule(hsh):
    return f'hash.sha256(0, filesize) == "{hsh}"\n'

def print_vt_rule(df, feedurl):
    import datetime 
    timestamp = datetime.datetime.now()

    x = map(create_rule, df['sha256'].tolist())
    formatted_lst = '            or '.join(list(x))
    s = f'''
import "hash"
rule covid19_indicator_match
{{
    meta:
        feed = "{feedurl}"
        created_on = "{timestamp}"
        total_indicators = {len(df)}
    condition:
        filesize < 1MB and
        (
            {formatted_lst}
        )
}}

    ''' 
    print(s)

# %% [markdown]
# ## Fetch the indicators and list some of them

# %%
import pandas as pd

df = get_feed(feedurl)
i = 5
print(f"Feed contains {len(df)} indicators. Listing {i} example indicators:")

df['Timestamp'] = pd.to_datetime(df['Timestamp'])
df.sort_values(by='Timestamp', ascending=True).tail(i)
# Out:
# Feed contains 309 indicators. Listing 5 example indicators:
#               Timestamp                                             sha256  \
# 218 2020-05-13 02:00:00  977820df24af8c83c1377290457cf7c0bab4f5634b1172...
# 219 2020-05-13 02:23:41  66ec588584fa4145e846df879dd3385a14f7a445b11299...
# 220 2020-05-13 02:35:44  262329dbb9e927ceaa1fb2eda4dd5ecd6d53f79664f412...
# 1   2020-05-14 05:41:38  c4a6245679676f18ab309dc7ca39ad7e70806bac16dd31...
# 304 2020-05-14 08:50:42  ccb9e262904aa7dd6cb3a529a2b77bebcd1d9dc51c9f2c...
#
#     IndicatorType    TLP         Product ThreatType  \
# 218        sha256  white  Azure Sentinel    Malware
# 219        sha256  white  Azure Sentinel    Malware
# 220        sha256  white  Azure Sentinel    Malware
# 1          sha256  white  Azure Sentinel    Malware
# 304        sha256  white  Azure Sentinel    Malware
#
#                               Description
# 218  Microsoft COVID-19 Threat Indicators
# 219  Microsoft COVID-19 Threat Indicators
# 220  Microsoft COVID-19 Threat Indicators
# 1    Microsoft COVID-19 Threat Indicators
# 304  Microsoft COVID-19 Threat Indicators

# %% [markdown]
# ## Construct Yara rule that matches the indicators

# %%
print_vt_rule(df, feedurl)
# Out:
# import "hash"
# rule covid19_indicator_match
# {
#     meta:
#         feed = "https://raw.githubusercontent.com/Azure/Azure-Sentinel/master/Sample%20Data/Feeds/Microsoft.Covid19.Indicators.csv"
#         created_on = "2020-05-18 11:04:57.103130"
#         total_indicators = 309
#     condition:
#         filesize < 1MB and
#         (
#             hash.sha256(0, filesize) == "d6332d4b5b5984ebb39685164428ad0f1f1b04e82b14cd5d773bbdd0d4ad05dc"
#             or hash.sha256(0, filesize) == "c4a6245679676f18ab309dc7ca39ad7e70806bac16dd31af1f769bca84044f47"
#             or hash.sha256(0, filesize) == "1789493dcb90022e86b162654f82c15e83553689e0810c2758ed49ab1b8e5611"
#             or hash.sha256(0, filesize) == "fa9463f9970d2b83ebe1eb734e8f04e540253e9be25761cdd600a30da22fffe5"
#             or hash.sha256(0, filesize) == "5b37cc85fd190a6b4726ea57f2588b5a74acc2c51e2917363c226b73ac79118f"
#             or hash.sha256(0, filesize) == "5e3e874b7f87124567d4716a6f0e8d696bae261550b399649a9fb3a85f2e0d5a"
#             or hash.sha256(0, filesize) == "f3a681a139a02e055df273fa742ef908e7340da6b3f67a456628d3969e398590"
#             or hash.sha256(0, filesize) == "0c7652ae9d73e4760e790d57eac5f8d4e31db7fa0e1124aa0d2bd8b24cbdbe7a"
#             or hash.sha256(0, filesize) == "1eda6158b488a4f6635255b406b59933d4dc6877e1cac1bb85e1d9bfd9cd7f62"
#             or hash.sha256(0, filesize) == "7a458a8a80f9f3d17724244daba45caf8ba8692463260c3f417946f2656e5fd8"
#             or hash.sha256(0, filesize) == "a42f4b31d3cac6a81b4f5c2712baebe2c56ce3293c40551b0f3fc894ebe3f837"
#             or hash.sha256(0, filesize) == "56a4523b72aef34982a90a480c17386862d4788c0501b9982d798d43c860cc6c"
#             or hash.sha256(0, filesize) == "bbb0f2855d1444cae835700f58acb51b6a6fd2f48046e94850982753cb4a7268"
#             or hash.sha256(0, filesize) == "e84b6245f19f01b8b9467e14501d114a19f5dbbd26f92f7823ec7f02cff6dda5"
#             or hash.sha256(0, filesize) == "1aab7341b71b0b99596d441e662d546b07ac216c33482082f87f3bdc2aee0ab7"
#             or hash.sha256(0, filesize) == "9defcf42437175c34b7159516c8b0b51f169213544a906d57ed476edf69eac2d"
#             or hash.sha256(0, filesize) == "f37321890a082784a11d632fae9e4264443cd9e437578cd03dfc4c665a9bfcff"
#             or hash.sha256(0, filesize) == "94574a42bbe0f0c01c75740b7322f04893711f51b33e23d46fd488b502f548ed"
#             or hash.sha256(0, filesize) == "a616225f20b3753c02fd29b0d70730285ff9bca6bd6f12557bd4f2c58d66d469"
#             or hash.sha256(0, filesize) == "12bd1455e0941a797cc7ecc49f45c3679889caf5087bb1814bf78b0e9252a40e"
#             or hash.sha256(0, filesize) == "58ba6e95c40eae62e593bb6660a9e2b50775e2c8dca68fbd39f5b8ee045b85dd"
#             or hash.sha256(0, filesize) == "ace047701b28f1adff4067d2cb334977d59b6af1a435bfe4893f5f7de5e78b67"
#             or hash.sha256(0, filesize) == "e365e50d93e980faa1e1dba41c549e43d863a64ec8c4d171b086f591726f7ec9"
#             or hash.sha256(0, filesize) == "41dcf1c99f093209fa2af7b9054dcad95bb6b2412efdc22f9f9fbd9a212205bf"
#             or hash.sha256(0, filesize) == "ad2bea6fbbb8cb3e5eba28e8e186d1db7bc1b54e7d12bd1d8c11fe7a38263036"
#             or hash.sha256(0, filesize) == "372cf005761bbc6a2e100c1cf672e02817f0c29a22805b350efa83a2d589818c"
#             or hash.sha256(0, filesize) == "5065b6e9a7aa27da7482a9cc8746852946f2b78d696f27c3dd89fdd206dd5043"
#             or hash.sha256(0, filesize) == "bf13ebf7d878a81a6e7de188733ed69a9ac8225914ffaa2521baf88039c6f13e"
#             or hash.sha256(0, filesize) == "69c611c912f430b70e6c80e497be87b27b8fc91e36aae687fe5dd1012fd63a64"
#             or hash.sha256(0, filesize) == "54468d3114f4c4d12023757f47c3d094e1d43b2b5eb7c7c1ec6b43a616922a1b"
#             or hash.sha256(0, filesize) == "fc787c9d98357f7b5951d48796f67929e806f67e3005116e2c0c7aa1430e24d1"
#             or hash.sha256(0, filesize) == "d8dedf7e0bddd259ffad62b1fe6c1aead7d9e599390161dc479bb53f7cb1fa8e"
#             or hash.sha256(0, filesize) == "ad2d9451a2530f7844dd60df335f39625dcf64baa55040252e4975df19451c8a"
#             or hash.sha256(0, filesize) == "6e0c15ea60cba8ff20ee8e57bfbf0b61d6d9d669ee0b0f264714838ef1554495"
#             or hash.sha256(0, filesize) == "76cde1ba2cb28616f188765c5e848ec833ba3327e7baf91b0363dc2eca9f1a4f"
#             or hash.sha256(0, filesize) == "a7cc5f0cac0ca7b56f7929ef8d26af58dd479c00a2deaf075fd4320867dd35c3"
#             or hash.sha256(0, filesize) == "17a75983ad095e2d8b8d575be71aaddbb62e5a56833dca55c3197d0dcc5d2193"
#             or hash.sha256(0, filesize) == "04f8758d329d09e33fd0bfea533e939934db5edf923d515218a061772e1e5c2a"
#             or hash.sha256(0, filesize) == "508ab10d87c9d3b8c9725aeae7a8668bd90dd687de6233ad35f59f5fa44a665c"
#             or hash.sha256(0, filesize) == "8f61fc223edce74d3816e26c247f64daf96135c9a69f9875ac74ba6719955585"
#             or hash.sha256(0, filesize) == "5d921bc1c708b911b472f69a7ec3f1200c8eda6dbf0cb68468c1d2edd8a4b6e5"
#             or hash.sha256(0, filesize) == "a883f5821ddc34d82927bfd4bbffe46c13bcea92519a3717a0fd4eee14562a5f"
#             or hash.sha256(0, filesize) == "645ad911f6b34cd0cbf054eeda2149993413fbc8a7b3a89e3a008cac31203e41"
#             or hash.sha256(0, filesize) == "8e644f1e051e43486028f298f2f3b77e16334f590dcb17b024503a2226c8daf7"
#             or hash.sha256(0, filesize) == "67584a05bb63f4a7dc8133ff02781cf4c276c2615d710f01d46c57398b7d2a12"
#             or hash.sha256(0, filesize) == "012c421327cfb117e588fcafcd0db8c46266f7a3f29d92096ce9ec19514d703b"
#             or hash.sha256(0, filesize) == "e0e03b7b356aa70a67dca61c864560075ec806a2b576084c36b4e994c6d3d8b6"
#             or hash.sha256(0, filesize) == "427b389d2abf8afa218368d4d685387f193311999ecc38eafc53db9eb419ce93"
#             or hash.sha256(0, filesize) == "4d9e9f760f18ce9f923223f0b82b3eecdbc21aa89daa70b8ee80789f3a1c08bc"
#             or hash.sha256(0, filesize) == "b563087d24589be4b0178b4c63ef45041e524171c65670ea19a9411f7d775731"
#             or hash.sha256(0, filesize) == "104aecfabd9a574db4dc4955d6da5f5141995b7e948c1724992db779302fd99e"
#             or hash.sha256(0, filesize) == "362358b130a90a74ac441bbc19a647e7db0587132bca436c8637fbf635e2dd11"
#             or hash.sha256(0, filesize) == "1d134f4a12b69a49579b158fabced1a00661cc30216c15637f8fdac8eaf1ed67"
#             or hash.sha256(0, filesize) == "d8bc32694b926af35b4df717d7b125a3418b0f398c9445434633618273080e59"
#             or hash.sha256(0, filesize) == "dfb832092fd984dee8d7e457647bd6d61ff25914d2cc938db89be7ba3b568d12"
#             or hash.sha256(0, filesize) == "09ad65c1f8ea16a8bc80738875b1b77eb692d90c7ad0b01641c212bde48bc034"
#             or hash.sha256(0, filesize) == "06916e30b3548a56c10ae2b704e452d633f5a4fe9ef21759069ba5841c1b1b15"
#             or hash.sha256(0, filesize) == "8c17386933d93788d5d4352df22eaea81076eb89ffa4dc92de1a8cf7df13dbf0"
#             or hash.sha256(0, filesize) == "82c74991938135d8abcb4a6de913dc31097c1bbc71fef92e8a976410d1b23e51"
#             or hash.sha256(0, filesize) == "5ff163a1eeadab8b3d1c3cc9fa3b2de91fd8431b1251640b3eb8432f32f9a1df"
#             or hash.sha256(0, filesize) == "5a86c02631ddef9ff1e1cb4243a7921cb2dd29b293f42477a4ac238d8e196a02"
#             or hash.sha256(0, filesize) == "9335011e12b8b321039ad436424b3edb1736d28b69ab229e691013a0a0650691"
#             or hash.sha256(0, filesize) == "ae993d2189850e9b8ddc29c7c56e0fbba8301bfc760105762f250c46c24934cf"
#             or hash.sha256(0, filesize) == "c0b5187da1ab8a5adae34fd2b1a5da26c79b96fe04f70bf4b4832fb90dc0f342"
#             or hash.sha256(0, filesize) == "78fb8adefdf2a2d283ad6c7c5b1620742f2fad2a01cd3d6261c4e207e5dd28d9"
#             or hash.sha256(0, filesize) == "9a768778fc789b65b0aa8c12ce7ecfcc59addfdc95df8f464ca14ea603cace60"
#             or hash.sha256(0, filesize) == "eedad2f242ae11c869b66e52f3f7a44e00f8b7bbd467ec0c112c06567c5f0afb"
#             or hash.sha256(0, filesize) == "f95be19d66c79f5503fbb2b60597cc6b780f33306a87789c910fa530ee4583e4"
#             or hash.sha256(0, filesize) == "d31c8ea615af83574be7b074b2e344bc4e3236566a566d64ebb67571e8bbbe0e"
#             or hash.sha256(0, filesize) == "9c669528c922a8786779a2cb4c168f5641c1682935249578e0303f7057ad1af6"
#             or hash.sha256(0, filesize) == "8c84f1941b42cd52ac285b7bc0dfb2e58c894d48868aceecf2ebf14aabfabb21"
#             or hash.sha256(0, filesize) == "53865fb0ad241aab260c6239cdcb71281c0aae293b0d441d759a3da536b27d6c"
#             or hash.sha256(0, filesize) == "2fbce6ab1fdca3fc54f48f4a53c09647078653a28b68a39d1892ed1d0292b74e"
#             or hash.sha256(0, filesize) == "f47ff6779bfcb1e4d552d51a13d0305e6ff5e39d95a3f9443729fe7bda4ad5f1"
#             or hash.sha256(0, filesize) == "dfc7737ef851b905d35ed685e3dbc95b8936bc1b75b20408f6bd3840d9f0cd51"
#             or hash.sha256(0, filesize) == "e117eeb14215e245525c53d20f53dac3af090e136d23731b28f4d46d0bd5b0e2"
#             or hash.sha256(0, filesize) == "a20a96a5c86dcfdd03b96512240bc80ae8924292d1cde9368ed3ef615bc9bb51"
#             or hash.sha256(0, filesize) == "74d02903c0651ab070f711a2c521bc70e5f7261b43dfddabb2034110fcc4bb44"
#             or hash.sha256(0, filesize) == "e3273ec51ccfaa9fd29e254450c7de575da1ecd81c3cb88af14f1701e8e11469"
#             or hash.sha256(0, filesize) == "be395ce164a59bb92d5fcab95d43dd3060c6aa4d36d42fb640c5be6a897d4046"
#             or hash.sha256(0, filesize) == "cc0e2ac3a476463782759843a4eb1db7566ae79ad2d9f7ea60af8cea45e5ce66"
#             or hash.sha256(0, filesize) == "74281cb395b871ab9932109b5f2bf91265e3146bf8e866a83ca1a1aafeeab789"
#             or hash.sha256(0, filesize) == "24fbd7e53c08e1347b0a0dbe20e74c87b330633b1a5bab5a2518d388287ba01e"
#             or hash.sha256(0, filesize) == "8a31752fc4ea9b873cc626f38201cdd218192ed25ccb62c43e0302f9ce165f5e"
#             or hash.sha256(0, filesize) == "a2dfa6ae61b538208f025a24343ef27714895913c988f63aa06b421bd24fc850"
#             or hash.sha256(0, filesize) == "4b3bd629f1cedef99690fc35f01ca75df00a5aa30319741ea42621c578cb7ebf"
#             or hash.sha256(0, filesize) == "280b92d00abbf7a35da09fc5a7ca7cbbc973437985e18aec778cd68d9646468e"
#             or hash.sha256(0, filesize) == "cf1c8ef824f2b73bd5da590e1aa82c5e0273707b2ac2fd32542b79d14473b5a8"
#             or hash.sha256(0, filesize) == "243b8ad8522d8decf1bcb423453e155e71a05000ec27e3eed86d342aa74242b1"
#             or hash.sha256(0, filesize) == "e383c72cee3f63dbe274846f60f0efa509f0140bc99754bb19f0bb53c9c3455b"
#             or hash.sha256(0, filesize) == "6b1e3acc87d704eb72cb7cd57ad5b3f29434e5f85a81dc6ded8ffa8a955a031d"
#             or hash.sha256(0, filesize) == "2df8d66e7e73abf902c397c1bf6727a6097f730eb280ff1af84d3e233c5b25f1"
#             or hash.sha256(0, filesize) == "5460262c64e501356d46e9a30fa1505f3192cacc262cb8c72cfa5a7c12cbe8a3"
#             or hash.sha256(0, filesize) == "a109903292dbcc76ef066e33665c46c4d1bd6995a4d5f177b33cdfaafa18e822"
#             or hash.sha256(0, filesize) == "1775a7972773815f71ab340c5703c331f864911ecb10b773797ae5f6dc574e73"
#             or hash.sha256(0, filesize) == "e85b78b833d684f35dc48a442992b4a2a04071d77f0dbe2a2c971e9eaa002155"
#             or hash.sha256(0, filesize) == "988226ff1089f55f9ae194319f68a9e1d52a9e502aaf7322163f9a6566cf5a8f"
#             or hash.sha256(0, filesize) == "efa3878e256474b80ad6270e23acf5d58c5eefea3c15299d28974cbac6cc00cf"
#             or hash.sha256(0, filesize) == "fdbe69ae281f910be58a49bdaa6f52b7019adc86d58a06362d047f18e9851ad3"
#             or hash.sha256(0, filesize) == "2968b4121477c3e776ae9baec7e2dea306f87fba86f885791185cecc5cf44daa"
#             or hash.sha256(0, filesize) == "120bd4e747239fb999f2485c0f47a56ff71f6d580688a33804d4e0f8f27af4c0"
#             or hash.sha256(0, filesize) == "f88bc1c75924b53d430ce58db79ce0158c1b0f3a989123f3b1c7d358c18978e0"
#             or hash.sha256(0, filesize) == "3bb98e418ee7d38bd42f87580194a16393ceb5a56b640989e8a0915dc2d8346e"
#             or hash.sha256(0, filesize) == "36994eabb775b8469f3a48f424e0a0fa13453ba4eb2fe86d9a31f0c7c93f1be9"
#             or hash.sha256(0, filesize) == "cc1ca9104ec1210b58bb56a292bec2a588e6ea229e9d650c82b41c835176b643"
#             or hash.sha256(0, filesize) == "681507a9b5260b75fa0bd86624575342c1efcbe8b55944a5926dcbee6630c420"
#             or hash.sha256(0, filesize) == "66898be3ec010413d79261012c58832cb53942b55a62f3cb7c3c720797b27b02"
#             or hash.sha256(0, filesize) == "585dc074676df3b0c5c9bc8bb2e3a03966feabfc3d4aa5ae8013da99264438f2"
#             or hash.sha256(0, filesize) == "ce8578ec6d01d8dadbd280172427be8f4f9c10d2214d6c34cd8d6a7bc16bcfa2"
#             or hash.sha256(0, filesize) == "40c1f776ede7ed4ef80d32331f5dec03f9d36410c589ff724c3714142b963cf4"
#             or hash.sha256(0, filesize) == "c085507cde62350fab658299465073062ee9ec8ef1ea2a1aec4a0e43b50c64bb"
#             or hash.sha256(0, filesize) == "7168b085dbe47ac72e9ba7a8d2c1340f44a3c6562db399a62305cb00534997da"
#             or hash.sha256(0, filesize) == "560d3663cf18af675d6ca19ebb6c015b16bc9e6f2e550737fe957f214c3fc9c7"
#             or hash.sha256(0, filesize) == "5b777493061de84539a1a86f9eb9850a9c5222a2d590d2dfd14e224010de6d69"
#             or hash.sha256(0, filesize) == "4fadc9196b47441592b238b88e2e67a2c2ce6a077f22c84aa69bbf12d2b135c7"
#             or hash.sha256(0, filesize) == "926224a7c0d5eb4afb0b8ebb744236f6d94adedb950fce330ebb6bcc7033aa67"
#             or hash.sha256(0, filesize) == "135681c6571f79e47d0db4c4ec09f02bda6eacd7115f2cff1736b610e05f4530"
#             or hash.sha256(0, filesize) == "457e49c3ac97954775fc577d39d01cb13ab073cea773e82e305c4527a57526a7"
#             or hash.sha256(0, filesize) == "8e5963dd1f83298169cfc5a32147b19920e5e525ab00cb22724e53237d555cf6"
#             or hash.sha256(0, filesize) == "c462b553744ec1c1dd3c499676f7e1788c83f44e402e06bdb3be432b5dcfda69"
#             or hash.sha256(0, filesize) == "c73dc76db27d42fd5275cd88b56c0abf4b462c596e0ade36cbe1663e6b9c6497"
#             or hash.sha256(0, filesize) == "a270072f7b836efb9be22d3674aa2b3c0e963535b9c69e4d6facb965466433a4"
#             or hash.sha256(0, filesize) == "8934e9eae405a82c3d7441a7f27ea088f75eda9c79bca5770ad9c91a21fb20c5"
#             or hash.sha256(0, filesize) == "1078d27f2873ddec4203062b5eca87a4b63917f1f970b3878fcfb31ecc16869c"
#             or hash.sha256(0, filesize) == "e7793a1c2d72d81b052e5e245323b5f61d10bee00ad14ba4ef59471e562f0fe0"
#             or hash.sha256(0, filesize) == "be49ec5e6e876483c6da0bf79869ac7e9d7f6d1a4e6d007b5f34e27eb9cd0b1d"
#             or hash.sha256(0, filesize) == "894ae011a0990003953e32ceef3f50f9e062db3a66fb4d982dc862043b34e6b0"
#             or hash.sha256(0, filesize) == "3a99a1d98b476df4e958347f0a60936acb0e0ef2f6bf2b5894632c382d0aa4f9"
#             or hash.sha256(0, filesize) == "b94a1ce2de17b216345f90872a174e13af4cb29f35ba606db4b18b34fc6f3002"
#             or hash.sha256(0, filesize) == "0ef011802282d404af8c2b847fbeac98e77e6011850cf0724bb29c1ecdfc002c"
#             or hash.sha256(0, filesize) == "94bc11b74c55c60ddd3ac943e9439b92a93f20fab5a576aa49923a0c77ef56c3"
#             or hash.sha256(0, filesize) == "ec6218d06b6326eb83f80573a9f7832a69978396fa92b292464375256b4cd947"
#             or hash.sha256(0, filesize) == "567a7d5f671dd290dd832dc06dd6a212e49a5e3dbdfdd50556f578994c941087"
#             or hash.sha256(0, filesize) == "4cab6cfbefc7d5b9e96a071c72d2dad97113bfea66f3e0b510eba33ec29cf13d"
#             or hash.sha256(0, filesize) == "2bd74397db248f043be2875586e71a3925bbd24794073a6b9d855a926c6902cf"
#             or hash.sha256(0, filesize) == "894e19d4e7dbc0194a1ddba2433706b7af924fcd10f5365c8752d005b27321de"
#             or hash.sha256(0, filesize) == "eec9f9fce8647fcb34a0e6747c8e8da3c38ba167704274627c6a3fb84c169ce5"
#             or hash.sha256(0, filesize) == "fcce57bb2557559bcde39a384ea96a6de047b8239e3e89f4e4dcfb976feaf70d"
#             or hash.sha256(0, filesize) == "dc3e020f71be8d36556546fa384f25f600e98f5cd0b6678e2fd85daa586a2ebc"
#             or hash.sha256(0, filesize) == "3b975c947c17e2512ad4477d77c08143064424670cd89688484838f1ed621e7e"
#             or hash.sha256(0, filesize) == "16cea86c6bd2d940d32b1f71b3f45908f7f9acdf05fdd92bc5a021c623a110d5"
#             or hash.sha256(0, filesize) == "3f8b6ab0929ff1a009258600db2d63ca68b2100c1946a64da496ac818e9af32c"
#             or hash.sha256(0, filesize) == "6c0a1fb5314799587942d4942066a116749a79489e0eb88de4e3aa9d19fe73f9"
#             or hash.sha256(0, filesize) == "2275c46e1baa185c430c11b41140229ab91d5d23563faa17b89bb0b328d13ff6"
#             or hash.sha256(0, filesize) == "ac7e02aad39c64b7855a4da15f1354d517edb4ed7cde1bb537684505a99b22a2"
#             or hash.sha256(0, filesize) == "b13b50984de84de29f442105d83fc34a8eb4cd3524561119b301788fde026dc7"
#             or hash.sha256(0, filesize) == "f3216bc83c80882fa1ebac59c79fc0426fc27c220c3a1405c319f66d4dea7b82"
#             or hash.sha256(0, filesize) == "b8c266145991d8a4a57ca8a06405d5e4624c9d3e099212872f00be1d4db62b5a"
#             or hash.sha256(0, filesize) == "5a4c5d3cfe5c2521340ddbd5d0f14ef66b3128bcc27f8a87e97f2642e40a9d80"
#             or hash.sha256(0, filesize) == "1d456c337289f784bbf374dbc24da94c8b7bf9bbc4cd255a467d70773ee23544"
#             or hash.sha256(0, filesize) == "f0d2379cb8a099c9aedb2b714c6aab5f73a5a321cd5eb6522930a2bb425570f2"
#             or hash.sha256(0, filesize) == "c60ccf6a15a3ea186811a8a51d705bec29dd72b31d3d5ec00331bcdcda6f5b2e"
#             or hash.sha256(0, filesize) == "bb50ab255ca6d68861af1c0d83a965a3003ec91aafcd472d5b7a0b7cc178b78e"
#             or hash.sha256(0, filesize) == "f1585106248a3604501b41e35a0c2aa5f89cf34603517c27462c651af3efacfd"
#             or hash.sha256(0, filesize) == "73ec050199c06122b1ea5dfda430800b7ef5f675cf2fa71b01f9acef82be2ce2"
#             or hash.sha256(0, filesize) == "062b8a8047d39dc643c7b01365881274e3c9dc7be7539a9967292e1b9891fc26"
#             or hash.sha256(0, filesize) == "24845094668e221848e76cdc522cbf674927367fa30f05a8d58a7ff3a702328b"
#             or hash.sha256(0, filesize) == "f307d942c33eeac429588a0581430f9ee0c8e8f2653c2ca3ad73e5547f7773ea"
#             or hash.sha256(0, filesize) == "3a715cf8c09708e3e03eae457e15cd7cc2f0aa9f315b4c7f37345ca959a982cc"
#             or hash.sha256(0, filesize) == "68f43c2d16a39c6ca2e871eb332a334ba4cfeb0e351e48a3e09cb74001d85a2f"
#             or hash.sha256(0, filesize) == "8b84789f2866e343b99ae9acf550038a306916485562237dbd8c9b0b84c7ebcb"
#             or hash.sha256(0, filesize) == "35689648646ee0e0b5af4559db064398b489f8afa5e66ffbc81acad0fe4b3470"
#             or hash.sha256(0, filesize) == "3e1c894016d3167052c5f284a591edb03950368b2b4692166e691650acba2f19"
#             or hash.sha256(0, filesize) == "efca2cdc10bfbd0d39e222c4c5f7e1e32d2755d1742140693bb3010babd8bf07"
#             or hash.sha256(0, filesize) == "5567e5de4de35774463479fd297ddcf25fb2d297ecfe2746baaf5c04a8e515ef"
#             or hash.sha256(0, filesize) == "0b4a771181af29e87416316ff1eac8a7f4b9e47a75e651defacdc711b0c362f2"
#             or hash.sha256(0, filesize) == "b050d2cb774a219142a2afb73de99e52c5590933a7a3d17a7c9dab392cb27ae8"
#             or hash.sha256(0, filesize) == "afff27ab2ad65b0594c7cad5bb1ee16cfdf343f634367ffacc11879ce2283bf2"
#             or hash.sha256(0, filesize) == "c16fe0d18632f69e7e8ff86c341f9d359913afadc62599fa5bf23cc76c8dbeb3"
#             or hash.sha256(0, filesize) == "221286f79d37f8181e44e6f530707c4f4f9699246a1ef54567ec4ff470200e7c"
#             or hash.sha256(0, filesize) == "7ac78d871ea7664146335ff0e727f195013f055d5b8984dcabef72ab099e9c27"
#             or hash.sha256(0, filesize) == "0360c64644aa1e1495d3b0d36c16e5883b553e654d902be74becacaa6b8609a3"
#             or hash.sha256(0, filesize) == "687da6a3f914342f0eb42ff9a613bd561df6725cfd7e413226603aa8c42fad7e"
#             or hash.sha256(0, filesize) == "4401d0cda816cbfea185441b6b7d0bdc73464c297328f6167435a98581806c59"
#             or hash.sha256(0, filesize) == "09d96d4fb65717de3958f3240fae6566ba8110b5c6924a0fdadb229d2021a448"
#             or hash.sha256(0, filesize) == "6114263b535e8b542eb503fad3f2ec06930e338648d45dbbdaf5b852cd05b155"
#             or hash.sha256(0, filesize) == "5b598402e0ba636c8d1c9b9240fc852b8a5a52207ff4ff9833b1a65b438fd86c"
#             or hash.sha256(0, filesize) == "c78408f7632d54526d8508574a3f0813553fa2823a9e43d5f0ac9c21f95394b7"
#             or hash.sha256(0, filesize) == "dcc49c4bce72f243e30f7503f01f17b3084152ac72613c4ba32a456a002bba9a"
#             or hash.sha256(0, filesize) == "43f4ef1cff48490a9018cbdf976a21b1f85a7ef307fd7bcc46227669a5590f23"
#             or hash.sha256(0, filesize) == "e70e4c4aca083fc21d84da808d518a46e6abd7ae77df03fb06177ea6bc810507"
#             or hash.sha256(0, filesize) == "d36dee90adc806b12a75c9ee2ebefe04daa1ab2a0332a04eff87101fec6a6e78"
#             or hash.sha256(0, filesize) == "d68eb9137e72b5f28bcb8ee9ddac983c0668cc47030813f9049c5940827744c6"
#             or hash.sha256(0, filesize) == "5e999c77d35eb0881e631a7fd80f68e67d3999d5e3ec62b804b044eee82ce1e6"
#             or hash.sha256(0, filesize) == "c7a02d3c4ec2db02db494baeeb04ebc7c8ff04697896010717efc42acceca20b"
#             or hash.sha256(0, filesize) == "9c1d1112d7534b3a12d05764e576e44b1d9b3b2662495de79b368b4228a42527"
#             or hash.sha256(0, filesize) == "33bbca3904c98524e79f53690fa089f8cc60b51e34a780d568e1d4769bc099d5"
#             or hash.sha256(0, filesize) == "8a88989eb3bf9d946af14db22902725405b9c6a99dced02756bb600ea6b22581"
#             or hash.sha256(0, filesize) == "f45668d410f0c830ba07727bc1c5b981033fdcabf1913990f0504e1d15c73c7c"
#             or hash.sha256(0, filesize) == "369267b5da48264bb89cfc7e651c4358d064f5f64a0eead7af94a5c7d68522f8"
#             or hash.sha256(0, filesize) == "ae2b2ffe6d3cfa645adacb43a78b27ae94cf2845e79a5cc593ca9618d4755672"
#             or hash.sha256(0, filesize) == "ff584dfac5f7f26b42b07a4c1f998ade361a6ba70e78d3e6a0ebcf58332bc9eb"
#             or hash.sha256(0, filesize) == "52b50878f98334bea7b778b4df0b87ff264b189be0dc7f098d4017a8a530f38a"
#             or hash.sha256(0, filesize) == "322949a2fdcd1521d8a038b93125ed56a62603ed0552c423e4f249cd063c020d"
#             or hash.sha256(0, filesize) == "c6c4958e56b65f2b5d3b6e4aabd16a812ef19f90aff33b20c8d1c5adf4a0f496"
#             or hash.sha256(0, filesize) == "3c83444663cad2927e7ea09e921809d4c41610cd749da360160b3a7fb426fe9b"
#             or hash.sha256(0, filesize) == "670c80e106a27e8ce4c53c6a01be043e1c788b0b520d0e65cea21822003ffbc9"
#             or hash.sha256(0, filesize) == "d5ffca3f12113512332fe1153a9b554294ba4014f928c6e0d00bf4625fd250ac"
#             or hash.sha256(0, filesize) == "f75e41f67c1600b8b461881b01cabfee3b3391c685671984e7cb063317058fef"
#             or hash.sha256(0, filesize) == "626275fb87012d3978d491d2bfb7ac692db691cfbc81455c13802f1e73184c1c"
#             or hash.sha256(0, filesize) == "ee395f226de27b3b92ac8f5cec7db30e065b6600726ec3a48b929dacd9d157be"
#             or hash.sha256(0, filesize) == "674430992c2c11cf6a4f4df3c1726ea2605bd7f1c60bd6a401fffa24d5682817"
#             or hash.sha256(0, filesize) == "61de45fe2249a73a9b488f300c2c88d20ab914ef17d936419935a56631337e6d"
#             or hash.sha256(0, filesize) == "b58a6f31ba53562fd6070de762458e1a1e5cdf3bdb786de310550ee5b7aaf368"
#             or hash.sha256(0, filesize) == "2883573cfdc6f600bc654cfa4f425e8d5588f75f05f27ef987f55a65484583c1"
#             or hash.sha256(0, filesize) == "8942d6fcf02c9485bc01466f88e6202304c9f7c8d689395961c893310d0e6a7f"
#             or hash.sha256(0, filesize) == "72c2edf9f10f964549ec340207384a58d4e4e6f8f188665423fbc7ef3831256b"
#             or hash.sha256(0, filesize) == "6b00e4c85ab9c2a0a724fc77177d5b55ff4369e5be068605a29fffe7173919f9"
#             or hash.sha256(0, filesize) == "0bdf233f60bf8f99b851487eaaf4db98da152bb6a19063b69bfc4b1f99abe523"
#             or hash.sha256(0, filesize) == "2fa6d5e132ec924a859ad584091b3fc256a74ca5c8f0f1a7fb3527376075bbec"
#             or hash.sha256(0, filesize) == "160a70bb6b9319a5d4353428d432a7f2bebfcbf174389d04bf299283c9ff87a6"
#             or hash.sha256(0, filesize) == "da339b6321307c56de9ec7c2098235cd4a2cae8b036dd9b4cf842f7a85aa38f8"
#             or hash.sha256(0, filesize) == "45fb984ff9e2cd4d17b9f5f4406e0fc07097b07c4f4b3e946d31b288ba49cc41"
#             or hash.sha256(0, filesize) == "5cc78424506168f686a671c9b7eff7b94a2cdd8a145c98e8d09ec8c0fca1604c"
#             or hash.sha256(0, filesize) == "1ff9615577cc6cd702d847672a34260a72ba5a71f4b7dd5ebfd844d4835c68a7"
#             or hash.sha256(0, filesize) == "808b264e94e12f42407ea2d1d4e730c24dd764b5567aea3db71b6862b77c240b"
#             or hash.sha256(0, filesize) == "3d69a1d2fb4c80138cecc9bad619edd65cf8edad2c756044564021d8e926c4b0"
#             or hash.sha256(0, filesize) == "efd0cb50d9524df945473e8e57bf2e12658c6e609e2b1c526acdce2b62a6f776"
#             or hash.sha256(0, filesize) == "977820df24af8c83c1377290457cf7c0bab4f5634b1172203b97924f52218ef1"
#             or hash.sha256(0, filesize) == "66ec588584fa4145e846df879dd3385a14f7a445b1129935f04d00915b348218"
#             or hash.sha256(0, filesize) == "262329dbb9e927ceaa1fb2eda4dd5ecd6d53f79664f4126d3943fbd0d11c545f"
#             or hash.sha256(0, filesize) == "59f33cb1848e34ade1e284e2126c62fb9f3da8dde14b469e7be9d562ab8f4350"
#             or hash.sha256(0, filesize) == "50a0367e0dc806e22c71c7bfcfe9c2446b47dbb7dbba35d0de812e2803d33461"
#             or hash.sha256(0, filesize) == "b379d23932b2dfe44979e5f0453acbc820b3461acf020403cb58f5da72fd9322"
#             or hash.sha256(0, filesize) == "1de98ea19569c3a644d523dc658a4a50d729bdc6e021e48543d6cea0c2c36992"
#             or hash.sha256(0, filesize) == "97624ddff8807a0b4abbb1dd3f9124e5f2835f086d7aa17b17cd416056b02ca5"
#             or hash.sha256(0, filesize) == "e80ca65c3142ad9cc047162640dd425ce6881dbaabea730d92a9c8ba85861d35"
#             or hash.sha256(0, filesize) == "fee642aa846f162593a03930d0bb486e11264d22e63721dd46009f345a687a67"
#             or hash.sha256(0, filesize) == "8a9e144aaf80764cc99958dfabe0034ecb63692d4386b36677127d4b917727bf"
#             or hash.sha256(0, filesize) == "d0b1e4ad6f50b425c6ea7957474ba1e9c6f737ec83ba62f06be7086d5d32da34"
#             or hash.sha256(0, filesize) == "b58f7a1d09f33af25ec2249fa37b1ec8dcc4386d84d7a3aedebff6b41946d18d"
#             or hash.sha256(0, filesize) == "c6944ac4632690322d79f23f90a292bb3e68008809f9de4d54ecf933c35e0d27"
#             or hash.sha256(0, filesize) == "67376bfed7bf3fc26fa33fdac59ca55a85b503dab9553d109377b089295fdfb4"
#             or hash.sha256(0, filesize) == "6d10c2221927cef531ac130724ca663c4f0429690453c9f91f017a668198a484"
#             or hash.sha256(0, filesize) == "51cfb9dff94cbc413e4940ac834f215be1b1789dae650e605b12908b9949b66a"
#             or hash.sha256(0, filesize) == "53c3b62bf065ab724d02b4a7aca463ed26916b02e2c5d564697eaed5c53204b2"
#             or hash.sha256(0, filesize) == "b6f5af59ae1d7c4c907a27a4abe2f117cb1c3af58802118383d27bbbe0ed7d82"
#             or hash.sha256(0, filesize) == "80494cf612e49bd1de9721279d5223122a16aabf9bc1980cecf1f6c5f5e6a094"
#             or hash.sha256(0, filesize) == "96e1129f5ef79924eb18739891d01af2ce6b37b6a653f24aa27fb50666605f11"
#             or hash.sha256(0, filesize) == "0a670d99368b7fc0a2394f31437b820c64c2d93a49f7d6f81d824c7e881b595c"
#             or hash.sha256(0, filesize) == "866aad642771c000c61eb3f4990432f63bbaec2eb194f80ef4f45967b6d7ff32"
#             or hash.sha256(0, filesize) == "99e7a622b68b928b08b7dac99736ab49b9abb2ef9c1b5b84629d74a9e06ff9c7"
#             or hash.sha256(0, filesize) == "a7bc30c63fb485aa67f49d2048206e65d38945b5972eba318afcf931202e7365"
#             or hash.sha256(0, filesize) == "72566077693ec85bd5867e70d0c7f118d592e93498a152a51ea55fed4fdb2684"
#             or hash.sha256(0, filesize) == "f39175c8c3be63c297c08985893813652907929133e5388d50c8e00fa6999469"
#             or hash.sha256(0, filesize) == "496c161a1d6b8da9ee47c362b91fdf40ea5ce86a6ab5214381c6e53f4df40bb7"
#             or hash.sha256(0, filesize) == "e300d945b7940b388da8bd983fdae6c9b9e5f5242eb593133a75a37f38e5481a"
#             or hash.sha256(0, filesize) == "fe429ba5c3a8b684113fb267817f6a1c3969cf07651655ef5e096f71492a05a7"
#             or hash.sha256(0, filesize) == "27d7668ebe6862125a28015e7df2fbf5295499d29b23c382517b67ad302c4708"
#             or hash.sha256(0, filesize) == "542acb556aedb497d1e244e9a3b7b7dad1f047e9bd67053de5bbc3a3947b413a"
#             or hash.sha256(0, filesize) == "0f6c19b75d1f892411d25482e5af41586c9dd8f32cd73f1dc381a3a3c9a19186"
#             or hash.sha256(0, filesize) == "79db18d5bbca1bfe809e1062d9e9b9e4c44bd1492c4c7dc8c4ea4a5ba739d26f"
#             or hash.sha256(0, filesize) == "748c52b216c6d2fa7a653e6bc3f64eda37d8351641917088fb370177d0f415f4"
#             or hash.sha256(0, filesize) == "9cd31317fad3facf25d2a5d6d84f065b33a8e3d76011d5b61cf99db6fdb297e7"
#             or hash.sha256(0, filesize) == "ab81f4240dd8e9a8b5d2a26f66be6ef86ab5b800109d24f4c32e32be528cca77"
#             or hash.sha256(0, filesize) == "8997a34bd715efc105ef93facb9231a08283c2b8e9263dccd7754bb5cd34386c"
#             or hash.sha256(0, filesize) == "3c7d066a5d809c422782ef2cbc040df1fabafb3693d4fa36c086708ba6b1be1c"
#             or hash.sha256(0, filesize) == "d99cc5befe76c241f12e986032702bfa41bdbf3eb99ee9a2d959d59be01bc82a"
#             or hash.sha256(0, filesize) == "aa404a16a0dd6e0d96249eee7cbd204447f60c3266adac860963ba6024f834a9"
#             or hash.sha256(0, filesize) == "f291e1608513a52fcbe54283371854af368f912ad50245ca41312d5e76b58080"
#             or hash.sha256(0, filesize) == "efbed74d99a627dbbd88d6bc8adc8f7979796e7895b6e309c29e843ab9a3bd49"
#             or hash.sha256(0, filesize) == "6cb474d9f89d81d09f22c5fb0ed595c0cf26c78cf58d8eacdd785fc815a130bf"
#             or hash.sha256(0, filesize) == "ac8f4c833f6030d63fce773bae96e5794a7ca05269a371ffad1924362cabc518"
#             or hash.sha256(0, filesize) == "f1eb1eb7d571da5c7a83cd02866af295902e4f1ceedf9b5178b9bcbec7277c4a"
#             or hash.sha256(0, filesize) == "4ad127112f195dc182af11bed193a0c2f5df32b6ec0ad263754f85ce09d41f44"
#             or hash.sha256(0, filesize) == "aecae2c746dc53d238af426819e985a634c9e236d293f5917c85ba9c13f90528"
#             or hash.sha256(0, filesize) == "2313a9345d96aab2e3985fab633479a09e974de5f47d6f9302841dcaf5fb9fd7"
#             or hash.sha256(0, filesize) == "59bab1182a43b5a47165d1f341f760c5752aab1457661e66b916c3b14945bc40"
#             or hash.sha256(0, filesize) == "0db3342766ddbb7b382f69ae990a5046472a4be864629af710669aef3015b3fc"
#             or hash.sha256(0, filesize) == "dcce29222aa2f355f0d113e6427c95a037892ed33094adf2eec1aabebb549ae5"
#             or hash.sha256(0, filesize) == "d07081578ffe7861fc1133c3279902bf59e0c7d185d5286bb319f06b2a2dc334"
#             or hash.sha256(0, filesize) == "1de15f04383f439133567112a2169e225685cb3e9f39b56dc2eca8308838f321"
#             or hash.sha256(0, filesize) == "1911bc67cfa3a25036f916de754d18c452e087115a0a84fd9a5ccf82321554a3"
#             or hash.sha256(0, filesize) == "d632f8863bb1c4a38b931dfe01ae16245fbcf1b3ba300a3740963c40404a1895"
#             or hash.sha256(0, filesize) == "86d7ade13a168a1a9a82e1687a0df7ddfa95cc282071d12542d5a7453d88318c"
#             or hash.sha256(0, filesize) == "b26f3ebe74126fb58238f63f5c81fd676ee07b089317f06a68d7c82c9f4a9f33"
#             or hash.sha256(0, filesize) == "8669d812e8228661189d84dcea786d722455b9bb17e6dc2f40c7583c51181309"
#             or hash.sha256(0, filesize) == "5d70773c90d5e93aab518ce8ff2ce66cc487fb5b76645d7138ad6fb0c8cc880c"
#             or hash.sha256(0, filesize) == "20bc580ad6fb60f78d026d556d8da0490a815d166b6259be1b2aee1ef69828c3"
#             or hash.sha256(0, filesize) == "714b4e09c2235747aa8b15887ddce66d10e1cd7c3cc5cb15295aa28f7b5015ec"
#             or hash.sha256(0, filesize) == "482d350bda423f1e5d5ff434fb3f63fd2ce93fea222ae950883e8407a634350b"
#             or hash.sha256(0, filesize) == "e11f9dc3fbba2eaf509014d803ba5390e28159c1354c3a1828e80f9c1a18fe8d"
#             or hash.sha256(0, filesize) == "d74edcaaa6ddc6bc7cf502c7b1d2bee14ca138a73d1bf2dca807c21122180449"
#             or hash.sha256(0, filesize) == "89f426d8b9583baa90a66ebfc8f9b8709a517178cc57ce493260e9d8af37405f"
#             or hash.sha256(0, filesize) == "a216cbed81ae8514eecaac3b822fa95b72198c37d65b8b56d727a18baba5cd95"
#             or hash.sha256(0, filesize) == "2e1fdffb8432d20ce7c4d6b391d82527aa6dcdc5542b5055836a38b711c78c25"
#             or hash.sha256(0, filesize) == "d03777805ab363b44f68767745f7899b2a84a65e5af81da55cdcbf67a78433c4"
#             or hash.sha256(0, filesize) == "39136e1f4d7c7066553b5dc060871b4a208639f122aacde80189c6e76a8eadb6"
#             or hash.sha256(0, filesize) == "aafa48e0340b23f18ad63c3a0a48d36364564169fa304eac0c321cfe5c043350"
#             or hash.sha256(0, filesize) == "9fa91f9946833f01406602d341d4dc774573a0b730e1628af8ea895fb5765252"
#             or hash.sha256(0, filesize) == "88c8a0233ac5325c8f7de572e0d4a87d94e47956e4cd4bdecc83cbfe634eb966"
#             or hash.sha256(0, filesize) == "5ec342b498fa68dd8afa4be45b714b9fed0cec50d14393fe99499ae71e8b65aa"
#             or hash.sha256(0, filesize) == "49ed634fdcbe9d161aaad319873bc7bd5e3155e3adfca684d449f5750b9d9623"
#             or hash.sha256(0, filesize) == "e0e7ea098e3c913d9ffe7ebee4e4b66e423e4605fa573e107ee7b5f26c03ef5a"
#             or hash.sha256(0, filesize) == "f43aa628bb959fffc60723c2f5e916c03988bb74f3ffe03dc87e83751c620bbc"
#             or hash.sha256(0, filesize) == "60aad5398d109b19928219f2c8b38f27baee1aa6da45d756054267e36dfe63ae"
#             or hash.sha256(0, filesize) == "501ac08ebac646517b00d3234dfe58837b460bd5f045822d9fb5999f00979bfe"
#             or hash.sha256(0, filesize) == "64b46aeb798cf62e8636e740d5c96d07923b65f62ce9a81faa8e877943a6a57f"
#             or hash.sha256(0, filesize) == "66301a2a7ca484fbba15150dd58b3e37bcc14ef0c56086556a338dfb267fc25e"
#             or hash.sha256(0, filesize) == "f51912bc834b37988c3c0a6671968bcdb9ab3a8aa580768bee2e19465ba42af5"
#             or hash.sha256(0, filesize) == "d42a1fd60954189c93509bc921f188b7583a7c5849c7f2436922ad4babd5b374"
#             or hash.sha256(0, filesize) == "3f6aca2b590e7fa767d8e85bf814688db1f449a7afac10994221b6a82c85a73a"
#             or hash.sha256(0, filesize) == "bfbada8b0ecc1f711dd4869c7fc97f658b88dc497a415a2e912eff9245fe9c9b"
#             or hash.sha256(0, filesize) == "76888b745714b1d0db8cd883eaac756c560b052462cae240c3917c441c07d611"
#             or hash.sha256(0, filesize) == "ccb9e262904aa7dd6cb3a529a2b77bebcd1d9dc51c9f2c1d8ededfc1a3c2040d"
#             or hash.sha256(0, filesize) == "1b25c9271d2bcd4e351b29ab29067fd8bf2d7a3058b87a45ee650de8d9b01aa4"
#             or hash.sha256(0, filesize) == "3d1502994590190cebb1aa35fc485fb2087716d7a51ba107b7d1bbcf89fd7733"
#             or hash.sha256(0, filesize) == "c772e0499021ddca199a0ab74f74b5c030502b2b5dc9126bba4b701173e1ac9a"
#             or hash.sha256(0, filesize) == "6237a300a4a51d95762f4b659706ed19879f1314201cffd35fa0e638d527373b"
#
#         )
# }

# %% [markdown]
# ## Search VirusTotal for any matching indicators (requires API key)

# %%
# if you want to query VT, define your API KEY
VT_APIKEY = '<insert api key here>'

# %%
def vt_search(qry):
    import requests
    import json
    
    if '<' in VT_APIKEY:
        print('Define your API key in VT_APIKEY variable')
        return []
    
    lst = []
    url = "https://www.virustotal.com/api/v3/intelligence/search"
    params = {'descriptors_only': True, 
              'query':qry,
             'limit':200}
    headers = {'x-apikey': VT_APIKEY,
            'Accept': 'application/json'}    

    r = requests.get(url, params=params, headers=headers)
    if r.status_code==404:
        print('hash %s does not exist on VT' % qry)
    else:
        results = json.loads(r.content)
        if 'data' not in results or len(results['data']) == 0:
            return lst;
        else:
            for x in results['data']:
                lst.append(x['id'])
    return list(set(lst))

def query_for_indicators(lst):
    partitions = int(len(lst) / 25)
    subs = [lst[i::partitions] for i in range(partitions)] 
    r = []
    for sub in subs:
        r = r + vt_search('\n'.join(sub))
    return r

# %%
lst = df['sha256'].tolist()
matches = query_for_indicators(lst)
print(len(matches))
# Out:
# 33

# %%
matches
# Out:
# ['bbb0f2855d1444cae835700f58acb51b6a6fd2f48046e94850982753cb4a7268',
#  'd6332d4b5b5984ebb39685164428ad0f1f1b04e82b14cd5d773bbdd0d4ad05dc',
#  'd42a1fd60954189c93509bc921f188b7583a7c5849c7f2436922ad4babd5b374',
#  '866aad642771c000c61eb3f4990432f63bbaec2eb194f80ef4f45967b6d7ff32',
#  'e84b6245f19f01b8b9467e14501d114a19f5dbbd26f92f7823ec7f02cff6dda5',
#  'c4a6245679676f18ab309dc7ca39ad7e70806bac16dd31af1f769bca84044f47',
#  '3f6aca2b590e7fa767d8e85bf814688db1f449a7afac10994221b6a82c85a73a',
#  'bfbada8b0ecc1f711dd4869c7fc97f658b88dc497a415a2e912eff9245fe9c9b',
#  '1789493dcb90022e86b162654f82c15e83553689e0810c2758ed49ab1b8e5611',
#  '1078d27f2873ddec4203062b5eca87a4b63917f1f970b3878fcfb31ecc16869c',
#  '72566077693ec85bd5867e70d0c7f118d592e93498a152a51ea55fed4fdb2684',
#  '76888b745714b1d0db8cd883eaac756c560b052462cae240c3917c441c07d611',
#  '5b37cc85fd190a6b4726ea57f2588b5a74acc2c51e2917363c226b73ac79118f',
#  'ccb9e262904aa7dd6cb3a529a2b77bebcd1d9dc51c9f2c1d8ededfc1a3c2040d',
#  '5e3e874b7f87124567d4716a6f0e8d696bae261550b399649a9fb3a85f2e0d5a',
#  '59f33cb1848e34ade1e284e2126c62fb9f3da8dde14b469e7be9d562ab8f4350',
#  'f3a681a139a02e055df273fa742ef908e7340da6b3f67a456628d3969e398590',
#  'f43aa628bb959fffc60723c2f5e916c03988bb74f3ffe03dc87e83751c620bbc',
#  '3d1502994590190cebb1aa35fc485fb2087716d7a51ba107b7d1bbcf89fd7733',
#  '50a0367e0dc806e22c71c7bfcfe9c2446b47dbb7dbba35d0de812e2803d33461',
#  'b379d23932b2dfe44979e5f0453acbc820b3461acf020403cb58f5da72fd9322',
#  '0c7652ae9d73e4760e790d57eac5f8d4e31db7fa0e1124aa0d2bd8b24cbdbe7a',
#  '1eda6158b488a4f6635255b406b59933d4dc6877e1cac1bb85e1d9bfd9cd7f62',
#  '6237a300a4a51d95762f4b659706ed19879f1314201cffd35fa0e638d527373b',
#  '501ac08ebac646517b00d3234dfe58837b460bd5f045822d9fb5999f00979bfe',
#  '64b46aeb798cf62e8636e740d5c96d07923b65f62ce9a81faa8e877943a6a57f',
#  '7a458a8a80f9f3d17724244daba45caf8ba8692463260c3f417946f2656e5fd8',
#  'a42f4b31d3cac6a81b4f5c2712baebe2c56ce3293c40551b0f3fc894ebe3f837',
#  '66301a2a7ca484fbba15150dd58b3e37bcc14ef0c56086556a338dfb267fc25e',
#  '96e1129f5ef79924eb18739891d01af2ce6b37b6a653f24aa27fb50666605f11',
#  'f51912bc834b37988c3c0a6671968bcdb9ab3a8aa580768bee2e19465ba42af5',
#  '56a4523b72aef34982a90a480c17386862d4788c0501b9982d798d43c860cc6c',
#  '0a670d99368b7fc0a2394f31437b820c64c2d93a49f7d6f81d824c7e881b595c']
